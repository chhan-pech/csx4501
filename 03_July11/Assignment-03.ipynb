# %% [markdown]
# # Matplotlib

# %% [markdown]
# The following imports numpy.  Do similar imports for matplotlib.pyplot and pandas:

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# We're going to generate some plots of fictitious data that follow this equation:
#
# $$ y(x) = 4 + 2x - x^2 + 0.075x^3 $$
#
# The following cell generates our `x` and `y` arrays.

# %%
# The linspace() function returns evenly spaced numbers over a specified interval [start, stop, num].
# num = number of samples to generate

# %%
x = np.linspace(0, 10, 50)
y = 4 + 2*x - x**2 + 0.075*x**3

# %% [markdown]
# Use the matplotlib.pyplot module to make a plot of `y` against `x` (y vertically, x horizontally):

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# (Check your ranges in the plot to make sure that `x` values are plotted horizontally and `y` values are plotted vertically.)

# %%
# Print x and y and check their ranges against the graph

print(x) # Values range from 0 to 10, all positive
print(y) # Values range from -1 to 4, includes both positive and negative values
# Out:
# [ 0.          0.20408163  0.40816327  0.6122449   0.81632653  1.02040816
#   1.2244898   1.42857143  1.63265306  1.83673469  2.04081633  2.24489796
#   2.44897959  2.65306122  2.85714286  3.06122449  3.26530612  3.46938776
#   3.67346939  3.87755102  4.08163265  4.28571429  4.48979592  4.69387755
#   4.89795918  5.10204082  5.30612245  5.51020408  5.71428571  5.91836735
#   6.12244898  6.32653061  6.53061224  6.73469388  6.93877551  7.14285714
#   7.34693878  7.55102041  7.75510204  7.95918367  8.16326531  8.36734694
#   8.57142857  8.7755102   8.97959184  9.18367347  9.3877551   9.59183673
#   9.79591837 10.        ]
# [ 4.          4.36715144  4.6548292   4.8668582   5.00706338  5.07926969
#   5.08730206  5.03498542  4.92614472  4.76460488  4.55419086  4.29872757
#   4.00203997  3.66795298  3.30029155  2.9028806   2.47954509  2.03410994
#   1.57040009  1.09224048  0.60345604  0.10787172 -0.39068755 -0.88839684
#  -1.38143121 -1.86596571 -2.33817542 -2.7942354  -3.2303207  -3.6426064
#  -4.02726755 -4.38047922 -4.69841648 -4.97725438 -5.21316798 -5.40233236
#  -5.54092257 -5.62511369 -5.65108076 -5.61499885 -5.51304303 -5.34138837
#  -5.09620991 -4.77368273 -4.3699819  -3.88128246 -3.30375949 -2.63358805
#  -1.8669432  -1.        ]

# %% [markdown]
# Real data is usually noisy.  It may be noise from measurement, or "noise" in the sense that there are aspects of the data that aren't captured by the features that we measure.
#
# The following cell introduces some random noise into a new variable `y_with_noise` that equals `y + noise`

# %%
# generate 50 points from a normal 
# distribution that has mean = 0 and std dev = 1.5
noise = np.random.normal(0,1.5,50)

# this y is now the theoretical value + noise
y_with_noise = 4 + 2*x - x**2 + 0.075*x**3 + noise

# %% [markdown]
# Make a plot of y_with_noise against x:

# %%
plt.plot(x,y_with_noise)
plt.show()

# %% [markdown]
# Make a figure that includes
# * scatter plot of y_with_noise against x
# * line plot of y against x

# %%
plt.scatter(x, y_with_noise)
plt.plot(x, y)
plt.show()

# %% [markdown]
# Make the same plot again with:
# * labels for the x-axis and y-axis
# * a title
# * 16-pt font size for the labels and title
# * make the line blue
# * make the scatter points black

# %%
plt.scatter(x, y_with_noise, color='black')
plt.plot(x, y, color='blue')
plt.xlabel('X-AXIS', fontsize=16)
plt.ylabel('Y-AXIS', fontsize=16)
plt.title('Random Data Points in One Plot', fontsize=16)
plt.show()

# %% [markdown]
# Save the figure into a file named 'matplotlib-plot.png':

# %%
# Originally tried saving the file with just plt.savefig('matplotlib-plot.png')
# But image file came out blank. Had to bring the above code 
# into the same block in order for show an image of the plot. 

plt.scatter(x, y_with_noise, color='black')
plt.plot(x, y, color='blue')
plt.xlabel('X-AXIS', fontsize=16)
plt.ylabel('Y-AXIS', fontsize=16)
plt.title('Random Data Points in One Plot', fontsize=16)
plt.savefig('matplotlib-plot.png')

# %% [markdown]
# Generate the same plot using the figure and axes objects (you can use the matplotlib.pyplot module to generate the figure, but otherwise don't use matplotlib.pyplot.)
#
# * The documentation for matplotlib.axes -> https://matplotlib.org/stable/api/axes_api.html
# * The documentation for matplotlib.figure -> https://matplotlib.org/stable/api/figure_api.html
#
# Save the figure into the file 'figure-plot.png'

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.plot(x, y, color='blue')
ax.scatter(x, y_with_noise, color='black')
ax.set_xlabel('X-AXIS', fontsize=16)
ax.set_ylabel('Y-AXIS', fontsize=16)
ax.set_title('Random Data Points in One Plot', fontsize=16)
fig.savefig('figure-plot.png')

# %% [markdown]
# # Pandas

# %% [markdown]
# Use pandas to import the data from 'anscombe.csv' into a dataframe variable

# %%
df = pd.read_csv('anscombe.csv')

# %% [markdown]
# Print the first 2 rows of the dataframe:

# %%
print(df.iloc[:2]) # Alternative: df.head(2)
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95

# %% [markdown]
# Print the last 2 rows of the dataframe:

# %%
print(df.iloc[-2:]) # Alternative: df.tail(2)
# Out:
#    dataset    x     y
# 42      IV  8.0  7.91
# 43      IV  8.0  6.89

# %% [markdown]
# Print the number of rows and columns of the dataframe:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  44 non-null     object
#  1   x        44 non-null     float64
#  2   y        44 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB

# %% [markdown]
# Print the column names of the dataframe:

# %%
df.columns
# Out:
# Index(['dataset', 'x', 'y'], dtype='object')

# %% [markdown]
# Print the datatypes of each column:

# %%
df.dtypes
# Out:
# dataset     object
# x          float64
# y          float64
# dtype: object

# %% [markdown]
# Print summary statistics about the dataframe:

# %%
df.describe()
# Out:
#                x          y
# count  44.000000  44.000000
# mean    9.000000   7.500682
# std     3.198837   1.958925
# min     4.000000   3.100000
# 25%     7.000000   6.117500
# 50%     8.000000   7.520000
# 75%    11.000000   8.747500
# max    19.000000  12.740000

# %% [markdown]
# Print the values that are in the 'dataset' column:

# %%
df['dataset']
# Out:
# 0       I
# 1       I
# 2       I
# 3       I
# 4       I
# 5       I
# 6       I
# 7       I
# 8       I
# 9       I
# 10      I
# 11     II
# 12     II
# 13     II
# 14     II
# 15     II
# 16     II
# 17     II
# 18     II
# 19     II
# 20     II
# 21     II
# 22    III
# 23    III
# 24    III
# 25    III
# 26    III
# 27    III
# 28    III
# 29    III
# 30    III
# 31    III
# 32    III
# 33     IV
# 34     IV
# 35     IV
# 36     IV
# 37     IV
# 38     IV
# 39     IV
# 40     IV
# 41     IV
# 42     IV
# 43     IV
# Name: dataset, dtype: object

# %% [markdown]
# Use "loc" to print the first 10 rows:

# %%
df.loc[:9]
# Out:
#   dataset     x      y
# 0       I  10.0   8.04
# 1       I   8.0   6.95
# 2       I  13.0   7.58
# 3       I   9.0   8.81
# 4       I  11.0   8.33
# 5       I  14.0   9.96
# 6       I   6.0   7.24
# 7       I   4.0   4.26
# 8       I  12.0  10.84
# 9       I   7.0   4.82

# %% [markdown]
# Use "loc" to print the values from the first 10 rows of the 'x' column:

# %%
df.loc[:9,'x']
# Out:
# 0    10.0
# 1     8.0
# 2    13.0
# 3     9.0
# 4    11.0
# 5    14.0
# 6     6.0
# 7     4.0
# 8    12.0
# 9     7.0
# Name: x, dtype: float64

# %% [markdown]
# Use "loc" to print the rows for which `dataset` is equal to `III`:

# %%
df[df['dataset'] == 'III']
# Out:
#    dataset     x      y
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73

# %% [markdown]
# Make a line plot of y against x for dataset III:

# %%
III = df[df['dataset'] == 'III']
III.plot(x='x',y='y')
# Out:
# <AxesSubplot:xlabel='x'>

# %% [markdown]
# Make a scatter plot of y against x for dataset III:

# %%
III.plot(x='x',y='y', kind='scatter')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# Make scatter plots for the other 3 datasets:

# %%
I = df[df['dataset'] == 'I']
II = df[df['dataset'] == 'II']
IV = df[df['dataset'] == 'IV']

I.plot(x='x',y='y', kind='scatter')
II.plot(x='x',y='y', kind='scatter')
III.plot(x='x',y='y', kind='scatter')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# We're working with the datasets from Anscombe's quartet.  You can read about it [here](https://en.wikipedia.org/wiki/Anscombe%27s_quartet).
#
# Use that page to find the equation for the linear regression line of these datasets, and make a figure that includes:
# * a scatter plot of dataset I
# * a line plot of the linear regression line

# %%
# I tried adding a regression line using panda but couldn't 
# get the line to show on the graph; decided to import seaborn
# I.plot(x='x',y='y', kind='scatter')

import seaborn as sns

# y = 3.00 + 0.500x

# scatter plot without regression line.
sns.lmplot(x='x',y='y', fit_reg = False, data=I)

# scatter plot with regression line.
sns.lmplot(x='x',y='y', data=I, ci= None) # Remove confidence interval band

# %% [markdown]
# Make the same plot again with:
# * a title
# * 16-pt font size for the labels and title
# * make the line blue
# * make the scatter points black
# * save the figure into a file called 'anscombe-I.png'

# %%
sns.lmplot(x='x',y='y', data=I, scatter_kws={'color': 'black'}, line_kws={'color': 'blue'}, ci= None, height=4)
plt.title ("Anscombe's quartet: Dataset = I", size=16)
plt.xlabel("X-Axis", size=16)
plt.ylabel("Y-Axis", size=16)
plt.savefig('anscombe-I.png', bbox_inches='tight') # Added "bbox_inches" because title was cutoff

# %% [markdown]
# # End
